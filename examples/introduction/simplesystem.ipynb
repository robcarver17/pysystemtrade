# %%
# %matplotlib inline

# %%
# %run simplesystem.py
# Out:
# {'rule0': TradingRule; function: <function ewmac_forecast_with_defaults at 0x7f4eeca52af0>, data:  and other_args: }
# {'ewmac': TradingRule; function: <function ewmac_forecast_with_defaults at 0x7f4eeca52af0>, data:  and other_args: }
# Adding config defaults
# System base_system with .config, .data, and .stages: rules
# Calculating raw forecast EDOLLAR for ewmac
# Loading csv data for EDOLLAR
# index
# 2019-11-08    3.242413
# 2019-11-11    3.242413
# 2019-11-12    3.242413
# 2019-11-13    3.242413
# 2019-11-14    3.110210
# Freq: B, dtype: float64
# TradingRule; function: <function ewmac_forecast_with_defaults at 0x7f4eeca52af0>, data:  and other_args: Lfast, Lslow
# Adding config defaults
# Calculating raw forecast EDOLLAR for ewmac32
# Loading csv data for EDOLLAR
# Adding config defaults
# Calculating raw forecast EDOLLAR for ewmac32
# Loading csv data for EDOLLAR
# Adding config defaults
# Getting forecast scalar for ewmac32 over EDOLLAR
# ...

# %%
my_account.portfolio().plot()
# Out:
# Calculating pandl for portfolio
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-bfda72791b6b> in <module>
# ----> 1 my_account.portfolio().plot()
#       2
#
# ~/git/pysystemtrade/systems/system_cache.py in wrapper(self, *args, **kwargs)
#     709             this_stage = self
#     710
# --> 711             ans = system.cache.calc_or_cache(
#     712                 func,
#     713                 this_stage,
#
# ~/git/pysystemtrade/systems/system_cache.py in calc_or_cache(self, func, this_stage, protected, not_pickable, instrument_classify, *args, **kwargs)
#     566         if value is MISSING_FROM_CACHE:
#     567             # call the function. Note in the original function 'this_stage' was 'self'
# --> 568             value = func(this_stage, *args, **kwargs)
#     569             self.set_item_in_cache(
#     570                 value,
#
# ...
